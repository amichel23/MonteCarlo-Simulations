# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
#coin function

def coin_flip():
    return random.randint(0,1)

# %%
coin_flip()
# Out:
# 0

# %%
list1 = []

def mc(n):
    results = 0
    for i in range(n):
        flip_result = coin_flip()
        results = results + flip_result
        
        #calculating probability value
        prob_value = results/(i+1)
        
        #append the prob values to list
        list1.append(prob_value)
        
        #plot
        plt.axhline(y=0.5, color='r', linestyle='-')
        plt.xlabel('Iterations')
        plt.ylabel('Probability')
        plt.plot(list1)
        
    return results/n

# %%
answer = mc(10000)
print(f'Final value: {answer}')
# Out:
# Final value: 0.5057

# %% [markdown]
# After 10000 iterations, the probability of getting a tail is 0.5057. Used MC simulation to actually run 10000 coin flips
